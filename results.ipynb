# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from load import *
from process import *
from load import *
from analyze import *
from config import *
# Out:
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
#returns accident entries per month
accident_plot(AVIATION_ACCIDENTS)
# Out:
#   accident_date           operator fatalities         marker
# 0    1 Jan 2004   Thunder Airlines          0  International
# 1    1 Jan 2004   Japan Air System          0  International
# 2    3 Jan 2004     Flash Airlines        148  International
# 3    5 Jan 2004       Regional Air          0  International
# 4    5 Jan 2004  Austrian Airlines          0  International

# %%
google_trend_plot(SEARCH_QUERIES)
# Out:
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
#           date  airplane_crash_US  airplane_crash_world  airplane_accident_US  \
# 0   2004-01-01                 14                    25                    54
# 1   2004-02-01                 13                    24                    63
# 2   2004-03-01                 11                    19                    58
# 3   2004-04-01                 15                    26                    51
# 4   2004-05-01                 12                    20                    41
# ..         ...                ...                   ...                   ...
# 258 2025-07-01                 12                    23                    51
# 259 2025-08-01                  8                    12                    35
# 260 2025-09-01                  7                    10                    31
# 261 2025-10-01                  8                    10                    28
# 262 2025-11-01                 19                    21                    38
#
#      airplane_accident_world  US_average  worldwide_average period_month
# 0                         74        34.0               49.5   2004-01-01
# 1                         74        38.0               49.0   2004-02-01
# 2                         86        34.5               52.5   2004-03-01
# 3                         91        33.0               58.5   2004-04-01
# 4                         63        26.5               41.5   2004-05-01
# ..                       ...         ...                ...          ...
# 258                       49        31.5               36.0   2025-07-01
# 259                       43        21.5               27.5   2025-08-01
# 260                       35        19.0               22.5   2025-09-01
# 261                       31        18.0               20.5   2025-10-01
# 262                       36        28.5               28.5   2025-11-01
#
# [263 rows x 8 columns]

# %%
enplanements_plot(ENPLANEMENTS_CSV)
# Out:
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 5.96MB/s]
# Final cleaned DF:

# %%
accident_vs_trends_correlation(AVIATION_ACCIDENTS, SEARCH_QUERIES)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File ~/dsci510_fall2025_final_project/load.py:29, in get_accident_table_data(url_input)
#      28 try:
# ---> 29     content = requests.get(url, headers=headers)
#      30 except:
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      63 r"""Sends a GET request.
#      64
#      65 :param url: URL for the new :class:`Request` object.
#    (...)
#      70 :rtype: requests.Response
#      71 """
# ---> 73 return request("get", url, params=params, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/sessions.py:746, in Session.send(self, request, **kwargs)
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:902, in Response.content(self)
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#
# File ~/Library/Python/3.9/lib/python/site-packages/requests/models.py:820, in Response.iter_content.<locals>.generate()
#     819 try:
# --> 820     yield from self.raw.stream(chunk_size, decode_content=True)
#     821 except ProtocolError as e:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/response.py:1088, in HTTPResponse.stream(self, amt, decode_content)
#    1087 if self.chunked and self.supports_chunked_reads():
# -> 1088     yield from self.read_chunked(amt, decode_content=decode_content)
#    1089 else:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/response.py:1248, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1247 while True:
# -> 1248     self._update_chunk_length()
#    1249     if self.chunk_left == 0:
#
# File ~/Library/Python/3.9/lib/python/site-packages/urllib3/response.py:1167, in HTTPResponse._update_chunk_length(self)
#    1166     return None
# -> 1167 line = self._fp.fp.readline()  # type: ignore[union-attr]
#    1168 line = line.split(b";", 1)[0]
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     703 try:
# --> 704     return self._sock.recv_into(b)
#     705 except timeout:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1241, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1238         raise ValueError(
#    1239           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1240           self.__class__)
# -> 1241     return self.read(nbytes, buffer)
#    1242 else:
#
# File /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/ssl.py:1099, in SSLSocket.read(self, len, buffer)
#    1098 if buffer is not None:
# -> 1099     return self._sslobj.read(len, buffer)
#    1100 else:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 accident_vs_trends_correlation(AVIATION_ACCIDENTS, SEARCH_QUERIES)
#
# File ~/dsci510_fall2025_final_project/analyze.py:86, in accident_vs_trends_correlation(accident_url, queries_input)
#      85 def accident_vs_trends_correlation(accident_url, queries_input):
# ---> 86     accident_df = process_accident_data(accident_url)
#      87     # Convert accident dates to proper monthly periods
#      88     accident_df["period"] = (pd.to_datetime(accident_df["dates_cleaned"]).dt.to_period("M").dt.to_timestamp())
#
# File ~/dsci510_fall2025_final_project/process.py:41, in process_accident_data(url_input)
#      40 def process_accident_data(url_input:str):
# ---> 41     accident_df = get_accident_table_data(url_input)
#      42     if accident_df is None:
#      43         return ValueError("Error returning data values")
#
# File ~/dsci510_fall2025_final_project/load.py:31, in get_accident_table_data(url_input)
#      29     content = requests.get(url, headers=headers)
#      30 except:
# ---> 31     raise ValueError("")
#      32 soup = BeautifulSoup(content.text, 'html.parser')
#      33 content_tables = soup.find('table', {"class": "hp"})
#
# ValueError:

# %%
fatalities_vs_trends_correlation(AVIATION_ACCIDENTS, SEARCH_QUERIES)
# Out:
#   accident_date           operator fatalities         marker
# 0    1 Jan 2004   Thunder Airlines          0  International
# 1    1 Jan 2004   Japan Air System          0  International
# 2    3 Jan 2004     Flash Airlines        148  International
# 3    5 Jan 2004       Regional Air          0  International
# 4    5 Jan 2004  Austrian Airlines          0  International
#
# Merged Data Preview:
#       period  fatality_count  US_average
# 0 2004-01-01             196        34.0
# 1 2004-02-01              58        37.5
# 2 2004-03-01              17        34.5
# 3 2004-04-01               1        33.5
# 4 2004-05-01              73        26.5
#
# Correlation between US Trend Score and Monthly Fatality Count: 0.2629
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
#         period  fatality_count  US_average
# 0   2004-01-01             196        34.0
# 1   2004-02-01              58        37.5
# 2   2004-03-01              17        34.5
# 3   2004-04-01               1        33.5
# 4   2004-05-01              73        26.5
# ..         ...             ...         ...
# 258 2025-07-01              60        31.5
# 259 2025-08-01              16        21.5
# 260 2025-09-01               3        19.0
# 261 2025-10-01              18        18.0
# 262 2025-11-01              14        28.5
#
# [263 rows x 3 columns]

# %%
accident_vs_international_trend_correlation(AVIATION_ACCIDENTS, SEARCH_QUERIES)
# Out:
#   accident_date           operator fatalities         marker
# 0    1 Jan 2004   Thunder Airlines          0  International
# 1    1 Jan 2004   Japan Air System          0  International
# 2    3 Jan 2004     Flash Airlines        148  International
# 3    5 Jan 2004       Regional Air          0  International
# 4    5 Jan 2004  Austrian Airlines          0  International
#
# Merged Data Preview:
#       period  accident_count  worldwide_average
# 0 2004-01-01              19               49.5
# 1 2004-02-01              17               49.0
# 2 2004-03-01              21               52.5
# 3 2004-04-01              22               58.5
# 4 2004-05-01              24               41.5
#
# Correlation between International Trend Score and Monthly Accident Count: 0.1436
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
#         period  accident_count  worldwide_average
# 0   2004-01-01              19               49.5
# 1   2004-02-01              17               49.0
# 2   2004-03-01              21               52.5
# 3   2004-04-01              22               58.5
# 4   2004-05-01              24               41.5
# ..         ...             ...                ...
# 258 2025-07-01              25               35.5
# 259 2025-08-01              15               27.0
# 260 2025-09-01              10               22.5
# 261 2025-10-01               9               20.5
# 262 2025-11-01               3               28.5
#
# [263 rows x 3 columns]

# %%
fatalities_vs_international_trend_correlation(AVIATION_ACCIDENTS, SEARCH_QUERIES)
# Out:
#   accident_date           operator fatalities         marker
# 0    1 Jan 2004   Thunder Airlines          0  International
# 1    1 Jan 2004   Japan Air System          0  International
# 2    3 Jan 2004     Flash Airlines        148  International
# 3    5 Jan 2004       Regional Air          0  International
# 4    5 Jan 2004  Austrian Airlines          0  International
#
# Merged Data Preview:
#       period  monthly_fatalities  worldwide_average
# 0 2004-01-01                 196               49.5
# 1 2004-02-01                  58               49.0
# 2 2004-03-01                  17               52.5
# 3 2004-04-01                   1               58.5
# 4 2004-05-01                  73               41.5
#
# Correlation between International Trend Score and Monthly Fatalities: 0.4473
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
#         period  monthly_fatalities  worldwide_average
# 0   2004-01-01                 196               49.5
# 1   2004-02-01                  58               49.0
# 2   2004-03-01                  17               52.5
# 3   2004-04-01                   1               58.5
# 4   2004-05-01                  73               41.5
# ..         ...                 ...                ...
# 258 2025-07-01                  60               35.5
# 259 2025-08-01                  16               27.0
# 260 2025-09-01                   3               22.5
# 261 2025-10-01                  18               20.5
# 262 2025-11-01                  14               28.5
#
# [263 rows x 3 columns]

# %%
us_trend_vs_enplanements_lag_heatmap(ENPLANEMENTS_CSV, SEARCH_QUERIES)
#1 month lag
us_trend_vs_enplanements_lag_heatmap(ENPLANEMENTS_CSV, SEARCH_QUERIES, lag_months=1)
# 3-month lag
us_trend_vs_enplanements_lag_heatmap(ENPLANEMENTS_CSV, SEARCH_QUERIES, lag_months=3)
#6 month
us_trend_vs_enplanements_lag_heatmap(ENPLANEMENTS_CSV, SEARCH_QUERIES, lag_months=6)
# Out:
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 587kB/s]
# Final cleaned DF:
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 334kB/s]
# Final cleaned DF:
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 283kB/s]
# Final cleaned DF:
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 324kB/s]
# Final cleaned DF:
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:54: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])

# %%
international_trend_vs_enplanements_lag_heatmap(ENPLANEMENTS_CSV, SEARCH_QUERIES)
international_trend_vs_enplanements_lag_heatmap(ENPLANEMENTS_CSV, SEARCH_QUERIES, lag_months=1)
# 3-month lag
international_trend_vs_enplanements_lag_heatmap(ENPLANEMENTS_CSV, SEARCH_QUERIES, lag_months=3)
# 6-month lag
international_trend_vs_enplanements_lag_heatmap(ENPLANEMENTS_CSV, SEARCH_QUERIES, lag_months=6)
# Out:
# --- Loading data from Web URL: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jX... ---
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 2.55MB/s]
# Final cleaned DF:
# 1     period_raw  Domestic  International  Total     period
# 0   January 2000     41552           5394  46946 2000-01-01
# 1  February 2000     43724           5249  48973 2000-02-01
# 2     March 2000     52984           6447  59430 2000-03-01
# 3     April 2000     50349           6062  56413 2000-04-01
# 4       May 2000     52320           6342  58663 2000-05-01
# 1
# period_raw               object
# Domestic                  int64
# International             int64
# Total                     int64
# period           datetime64[ns]
# dtype: object
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# --- Loading data from Web URL: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jX... ---
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 5.41MB/s]
# Final cleaned DF:
# 1     period_raw  Domestic  International  Total     period
# 0   January 2000     41552           5394  46946 2000-01-01
# 1  February 2000     43724           5249  48973 2000-02-01
# 2     March 2000     52984           6447  59430 2000-03-01
# 3     April 2000     50349           6062  56413 2000-04-01
# 4       May 2000     52320           6342  58663 2000-05-01
# 1
# period_raw               object
# Domestic                  int64
# International             int64
# Total                     int64
# period           datetime64[ns]
# dtype: object
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# --- Loading data from Web URL: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jX... ---
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 4.96MB/s]
# Final cleaned DF:
# 1     period_raw  Domestic  International  Total     period
# 0   January 2000     41552           5394  46946 2000-01-01
# 1  February 2000     43724           5249  48973 2000-02-01
# 2     March 2000     52984           6447  59430 2000-03-01
# 3     April 2000     50349           6062  56413 2000-04-01
# 4       May 2000     52320           6342  58663 2000-05-01
# 1
# period_raw               object
# Domestic                  int64
# International             int64
# Total                     int64
# period           datetime64[ns]
# dtype: object
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
# /Users/bernardyu/Library/Python/3.9/lib/python/site-packages/gdown/parse_url.py:48: UserWarning: You specified a Google Drive link that is not the correct link to download a file. You might want to try `--fuzzy` option or the following url: https://drive.google.com/uc?id=None
#   warnings.warn(
# --- Loading data from Web URL: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jX... ---
# Downloading...
# From: https://docs.google.com/spreadsheets/d/1Zxxlbj3-jXBdDsURy_9wI5mkQD-o8g3IH3eDGBs6dgQ/export?format=csv
# To: /Users/bernardyu/dsci510_fall2025_final_project/enplanements.csv
# 9.49kB [00:00, 2.15MB/s]
# Final cleaned DF:
# 1     period_raw  Domestic  International  Total     period
# 0   January 2000     41552           5394  46946 2000-01-01
# 1  February 2000     43724           5249  48973 2000-02-01
# 2     March 2000     52984           6447  59430 2000-03-01
# 3     April 2000     50349           6062  56413 2000-04-01
# 4       May 2000     52320           6342  58663 2000-05-01
# 1
# period_raw               object
# Domestic                  int64
# International             int64
# Total                     int64
# period           datetime64[ns]
# dtype: object
# /Users/bernardyu/dsci510_fall2025_final_project/process.py:53: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   trend_df["date"] = pd.to_datetime(trend_df["date"])
#                    worldwide_average  Domestic  International     Total
# worldwide_average           1.000000 -0.036854      -0.020127 -0.034574
# Domestic                   -0.036854  1.000000       0.912883  0.997783
# International              -0.020127  0.912883       1.000000  0.938030
# Total                      -0.034574  0.997783       0.938030  1.000000
